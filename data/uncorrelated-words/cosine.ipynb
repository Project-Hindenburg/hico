# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("selected_llama31_layer0.txt.cosine.tsv", sep="\t")

# %%
df
# Out:
#           word  preserving        td  blackout    albeit  plagiarism  \
# 0   preserving    1.000000 -0.050465 -0.018001 -0.008652   -0.003837
# 1           td   -0.050465  1.000000 -0.020956 -0.011558    0.002042
# 2     blackout   -0.018001 -0.020956  1.000000 -0.020881   -0.001569
# 3       albeit   -0.008652 -0.011558 -0.020881  1.000000   -0.006790
# 4   plagiarism   -0.003837  0.002042 -0.001569 -0.006790    1.000000
# ..         ...         ...       ...       ...       ...         ...
# 59       hoses    0.017808  0.011900  0.010609  0.024463    0.016695
# 60     grinder    0.024747  0.015829  0.022514  0.005886    0.008027
# 61        stap    0.023353  0.021408  0.010907 -0.008917    0.007187
# 62     standby    0.015592  0.012188  0.045892  0.003888    0.019040
# 63           a    0.034706  0.036791  0.021415  0.008836    0.024023
#
#         mote     dildo  stricter  improvised  ...       obe  subtitle  \
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(df.set_index("word"), cmap="coolwarm")
plt.title("Cosine Similarity between Tokens in LLaMA 3.1 Layer 0")
plt.show()
